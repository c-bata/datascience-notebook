# %% [markdown]
# # Seabornを使った可視化
#
# SeabornはmatplotlibベースのVisualizationライブラリです。

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## 散布図

# %%
iris = sns.load_dataset('iris')

# %%
sns.regplot('sepal_width', 'sepal_length', data=iris, ax = ax)

# %%
iris = sns.load_dataset('iris')

fig, ax = plt.subplots(figsize=(7, 7))
sns.regplot('sepal_width', 'sepal_length', data=iris, ax=ax)

plt.show()

# %% [markdown]
# ## 折れ線グラフ

# %% [markdown]
# ## 棒グラフ

# %% [markdown]
# ## ヒストグラム

# %% [markdown]
# ## 箱ひげ図

# %% [markdown]
# ---

# %% [markdown]
# # ファイルへの出力

# %% [markdown]
# 画像を読み込む
#
# ![](example.png)
